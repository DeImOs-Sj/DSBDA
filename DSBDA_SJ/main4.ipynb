# %%
import pandas as pd

# %%
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in ./env/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: scipy>=1.6.0 in ./env/lib/python3.10/site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./env/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in ./env/lib/python3.10/site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: numpy>=1.19.5 in ./env/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error

# %%
data=pd.read_csv("/home/shlok/Desktop/DSBDA Practical Assignments/Assignment 4/boston-housing/train.csv")

# %%
data.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
data.tail()
# Out:
#       ID     crim   zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 328  500  0.17783  0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9

# %%
data.isnull().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
#        'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
x=data[['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad','tax', 'ptratio', 'black', 'lstat',]]
y=data[['medv']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=29)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.7368520652319117

# %%
model.score(x_test,y_test)
# Out:
# 0.6944946540853632

# %%
y_pred=model.predict(x_test.values)
# Out:
# /home/shlok/Desktop/DSBDA Practical Assignments/env/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_pred
# Out:
# array([[34.69728512],
#        [24.76090248],
#        [24.21221405],
#        [10.34816016],
#        [25.46855004],
#        [20.64711327],
#        [28.10502141],
#        [25.24769393],
#        [20.92435169],
#        [16.24287697],
#        [44.20138699],
#        [20.93636612],
#        [23.55420738],
#        [19.85985304],
#        [16.31887112],
#        [28.9450061 ],
#        [37.45114184],
#        [15.90087195],
#        [20.59708102],
#        [12.21529079],
#        [21.60486838],
#        [ 8.87690978],
#        [30.12354063],
#        [19.89687729],
#        [22.14291219],
#        [25.27526108],
#        [16.71180496],
#        [45.68220084],
#        [-1.81210078],
#        [20.81350206],
#        [22.1890389 ],
#        [42.47011178],
#        [33.11110419],
#        [17.02128525],
#        [31.03058102],
#        [30.5455241 ],
#        [19.22670702],
#        [29.3373699 ],
#        [29.60848043],
#        [39.98062597],
#        [13.60858393],
#        [22.59611123],
#        [22.99535735],
#        [27.2917426 ],
#        [31.63936543],
#        [18.35440368],
#        [28.27687117],
#        [25.11077239],
#        [27.9609698 ],
#        [26.70921856],
#        [24.89454109],
#        [19.71278412],
#        [34.95097774],
#        [31.10314197],
#        [12.11145194],
#        [18.16305885],
#        [13.3011065 ],
#        [38.03216771],
#        [ 5.59475687],
#        [25.87094758],
#        [13.2733672 ],
#        [19.09770662],
#        [27.89617726],
#        [33.15991495],
#        [ 6.16780841],
#        [13.94887259],
#        [33.51269645],
#        [26.54094254],
#        [26.41656244],
#        [41.46820185],
#        [28.78956636],
#        [24.74084067],
#        [20.22523943],
#        [18.28422654],
#        [30.08894482],
#        [38.91035285],
#        [18.13142296],
#        [19.37773139],
#        [25.63520258],
#        [31.76658959],
#        [33.49645454],
#        [22.81149646],
#        [30.35650137],
#        [24.47416524],
#        [13.2128607 ],
#        [16.46406056],
#        [25.60881017],
#        [23.0342923 ],
#        [23.65750076],
#        [24.6753589 ],
#        [18.73618064],
#        [19.52117326],
#        [13.2594776 ],
#        [19.97291504],
#        [22.63298122],
#        [ 0.22960241],
#        [14.77457295],
#        [20.89197468],
#        [28.14301505],
#        [ 8.85252   ],
#        [29.00873443],
#        [25.24854942],
#        [20.73399208],
#        [31.47915194],
#        [31.24002246],
#        [43.73206896],
#        [28.30517349],
#        [22.18670308],
#        [24.73864331],
#        [ 0.30188117],
#        [18.65938932],
#        [19.32424462],
#        [28.04616715],
#        [22.61095873],
#        [16.74746339],
#        [24.89077048],
#        [17.80462951],
#        [26.90384218],
#        [21.14627529],
#        [26.26256266],
#        [19.53831432],
#        [21.04535565],
#        [23.36346824],
#        [26.94523509],
#        [24.1607287 ],
#        [24.34157492],
#        [15.8721009 ],
#        [35.00859818],
#        [33.57048532],
#        [27.9967938 ],
#        [19.70250067],
#        [20.30434191],
#        [24.69692803],
#        [ 5.18056897],
#        [18.82189447],
#        [33.58067091],
#        [16.64037085],
#        [28.54895244],
#        [23.41066452],
#        [23.7415933 ],
#        [15.01536296],
#        [20.35843343],
#        [27.69175203],
#        [23.07589779],
#        [29.92889019],
#        [19.66959308],
#        [23.3508917 ],
#        [19.03618953],
#        [40.14352548],
#        [23.1005757 ],
#        [15.10817633],
#        [13.91730643],
#        [30.21570959],
#        [22.34561616],
#        [21.21726683],
#        [13.90007935],
#        [38.7533732 ],
#        [17.10330406],
#        [18.06656043],
#        [29.36455544],
#        [28.11806618],
#        [14.58209129],
#        [16.76259459],
#        [18.78253148],
#        [20.40066816],
#        [17.05309772],
#        [23.03421283],
#        [ 9.92628533],
#        [26.49349331],
#        [14.70351531],
#        [33.27180141],
#        [20.02613242],
#        [22.61107551],
#        [15.82808419],
#        [24.42479996],
#        [10.48075056],
#        [27.67385745],
#        [25.00115332],
#        [24.69230342],
#        [32.91361385],
#        [16.46092455],
#        [23.97183892],
#        [15.05344177],
#        [20.38067932],
#        [12.07853865],
#        [19.7442611 ],
#        [40.13006123],
#        [20.73378231],
#        [27.07650451],
#        [24.22749522],
#        [14.41237474],
#        [25.6735366 ],
#        [20.52150223],
#        [23.51920349],
#        [27.44593905],
#        [17.36761333],
#        [13.33767663],
#        [37.12833185],
#        [22.08013636],
#        [26.60200572],
#        [34.19014178],
#        [23.44786595],
#        [31.04233257],
#        [26.02678969],
#        [17.90966953],
#        [25.4299109 ],
#        [33.63625181],
#        [15.55487046],
#        [21.93450243],
#        [21.6881006 ],
#        [22.88743879],
#        [13.33955424],
#        [26.46867975],
#        [17.88685541],
#        [23.29172018],
#        [24.42631862],
#        [20.93437514],
#        [27.5750704 ],
#        [12.05527918],
#        [13.29284419],
#        [ 7.73032714],
#        [16.82398602],
#        [38.54822711],
#        [23.59949153],
#        [29.24239489],
#        [23.51376914],
#        [12.0812961 ],
#        [ 9.29031249],
#        [36.22535509],
#        [28.26054285],
#        [25.68995729],
#        [22.27992913],
#        [20.17826616],
#        [15.17322128],
#        [20.27113767],
#        [15.51450738],
#        [36.18715983],
#        [25.76907777],
#        [20.24083781],
#        [33.71153752],
#        [ 7.83384881],
#        [21.15903395],
#        [38.3027033 ],
#        [17.5430404 ],
#        [13.67528524],
#        [15.62082831],
#        [14.09411034],
#        [15.00371013],
#        [25.69867089]])

# %%
model.score(x_train,y_train)
# Out:
# 0.7368520652319117

# %%
model.score(x_test,y_test)
# Out:
# 0.6944946540853632

# %%
model.intercept_
# Out:
# array([38.44267638])

# %%
print("MSE",metrics.mean_squared_error(y_test,y_pred))
# Out:
# MSE 23.215193557380456

# %% [raw]
# print()

# %%
print("MAE",metrics.mean_absolute_error(y_test,y_pred))
# Out:
# MAE 3.4298657074390073

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()
